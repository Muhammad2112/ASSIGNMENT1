# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad2112/ASSIGNMENT1/blob/main/Online_class3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world !")
# Out:
# Hello world !

# %%
name = "Muhammad Shaheer"
print(name)
# Out:
# Muhammad Shaheer

# %%
# python indentation

if(True):
  print("True")
else:
  print("False")
# Out:
# True

# %%
age: int = 20
print(type(age))

dec_num : float = 24.8
print(type(dec_num))

# num1= 24
# num2= 10.00
# print(num1 + num2)
# print(type(num1 + num2))

num1= "20"
num2= "10"
print(num1 + num2)
print(type(num1 + num2))

# numbers with real and imaginary part
num_complex : complex = 2+3j
# print(num_complex.real)
# print(num_complex.imag)
# print(type(num_complex))

sum = num_complex + 2j
print(sum)
sum1 = num_complex + 2
print(sum1)
# Out:
# <class 'int'>
# <class 'float'>
# 2010
# <class 'str'>
# (2+5j)
# (4+3j)

# %%
# BOOLEAN DATATYPE

is_student : bool = False
# print(is_student)
if(is_student ):
  print("Student")
else:
  print("Not student")
# Out:
# Not student

# %%
# SEQUENCE TYPE
name : str = "Shaheer"
print(type(name))

intro : str ="""My name is Shaheer
and age is 20 """
print("intro")
# Out:
# <class 'str'>
# intro
